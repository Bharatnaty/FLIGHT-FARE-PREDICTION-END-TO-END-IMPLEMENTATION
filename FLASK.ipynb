# %%
from flask import Flask,render_template,request,url_for,redirect
import pandas as pd
import pickle
app=Flask(__name__)
model=pickle.load(open("flight12.pkl","rb"))

@app.route("/")
def FrontEnd():
    return render_template("index1.html")
    
@app.route("/submit",methods=["POST","GET"])
def submit():
    if request.method=="POST":
        Airline=request.form["AirlineTime"]        #This is for airline
        if Airline=="IndiGo":
            IndiGo=1
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        
        elif Airline=="Air_India":
            IndiGo=0
            Air_India=1
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Jet_Airways":
            IndiGo=0
            Air_India=0
            Jet_Airways=1
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="SpiceJet":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=1
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Multiple_carriers":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=1
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="GoAir":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=1
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Vistara":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=1
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Air_Asia":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=1
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Vistara_Premium_economy":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=1
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Jet_Airways_Business":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=1
            Multiple_carriers_Premium_economy=0
            Trujet=0
        elif Airline=="Multiple_carriers_Premium_economy":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=1
            Trujet=0
        elif Airline=="Trujet":
            IndiGo=0
            Air_India=0
            Jet_Airways=0
            SpiceJet=0
            Multiple_carriers=0
            GoAir=0
            Vistara=0
            Air_Asia=0
            Vistara_Premium_economy=0
            Jet_Airways_Business=0
            Multiple_carriers_Premium_economy=0
            Trujet=1      
        #THE SOURCE FOR TRAVEL
        Source=request.form["Source"]
        if Source=="Banglore":
            S_Banglore=1
            S_Chennai=0
            S_Delhi=0
            S_Kolkata=0
            S_Mumbai=0
        elif Source=="Kolkata":
            S_Banglore=0
            S_Chennai=0
            S_Delhi=0
            S_Kolkata=1
            S_Mumbai=0
        elif Source=="Delhi":
            S_Banglore=0
            S_Chennai=0
            S_Delhi=1
            S_Kolkata=0
            S_Mumbai=0
        elif Source=="Chennai":
            S_Banglore=0
            S_Chennai=1
            S_Delhi=0
            S_Kolkata=0
            S_Mumbai=0
        elif Source=="Mumbai":
            S_Banglore=0
            S_Chennai=0
            S_Delhi=0
            S_Kolkata=0
            S_Mumbai=1
       
       
        Destination=request.form["Destination"]
        
        if Destination=="Delhi":
            D_Delhi=1
            D_Kolkata=0
            D_Hyderabad=0
            D_Banglore=0
            D_Cochin=0
        elif Destination=="Kolkata":
            D_Delhi=0
            D_Kolkata=1
            D_Hyderabad=0
            D_Banglore=0
            D_Cochin=0
        elif Destination=="Hyderabad":
            D_Delhi=0
            D_Kolkata=0
            D_Hyderabad=1
            D_Banglore=0
            D_Cochin=0
        elif Destination=="Banglore":
            D_Delhi=0
            D_Kolkata=0
            D_Hyderabad=0
            D_Banglore=1
            D_Cochin=0
        elif Destination=="Cochin":
            D_Delhi=0
            D_Kolkata=0
            D_Hyderabad=0
            D_Banglore=0
            D_Cochin=1
        
            
        Total_Stops=int(request.form["Total_Stops"])
        Route=int(request.form["Route"])
        
        
        dep_time=request.form["Dep_Time"]
        dep_time_hrs=int(pd.to_datetime(dep_time,format="%Y-%m-%dT%H:%M").hour)
        dep_time_min=int(pd.to_datetime(dep_time,format="%Y-%m-%dT%H:%M").minute)

        arrival_time=request.form["Arrival_Time"]
        arrival_time_hrs=int(pd.to_datetime(arrival_time,format="%Y-%m-%dT%H:%M").hour)
        arrival_time_min=int(pd.to_datetime(arrival_time,format="%Y-%m-%dT%H:%M").minute)

        Duration_hrs=abs(arrival_time_hrs-dep_time_hrs)

        pred=model.predict([[Route,Total_Stops,Air_Asia,Air_India,GoAir,IndiGo,Jet_Airways,Jet_Airways_Business,Multiple_carriers,Multiple_carriers_Premium_economy,SpiceJet,Trujet,Vistara,Vistara_Premium_economy,arrival_time_hrs,arrival_time_min,dep_time_hrs,dep_time_min,S_Banglore,S_Chennai,S_Delhi,S_Kolkata,S_Mumbai,Duration_hrs,D_Banglore,D_Cochin,D_Hyderabad,D_Kolkata,D_Delhi]])
        res=round(pred[0],2)
        return render_template("index1.html",res1=res)
        #return redirect(url_for("Result",res1=res))

    
if __name__=="__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Jun/2021 18:35:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jun/2021 18:35:39] "POST /submit HTTP/1.1" 200 -
